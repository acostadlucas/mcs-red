# %%
import requests
from bs4 import BeautifulSoup

# %%
# 1. Obtener el HTML de la página del ranking
url = "https://www.theglobaleconomy.com/rankings/unemployment_rate_monthly/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
response.raise_for_status()  # Lanza error si la petición falla

# %%
# 2. Parsear HTML con BeautifulSoup
soup = BeautifulSoup(response.text, "html.parser")

# %%
# 3. Buscar la tabla principal y extraer los links
table = soup.find("table")
country_links = []

if table:
    rows = table.find_all("tr")
    for row in rows:
        cell = row.find("td")
        if cell and cell.a:
            relative_link = cell.a["href"]
            full_url = f"https://www.theglobaleconomy.com{relative_link}"
            country_links.append(full_url)

# %%
# 4. Mostrar resultado
print("Links encontrados:", len(country_links))
for link in country_links:
    print(link)
# Out:
# Links encontrados: 106
# https://www.theglobaleconomy.com/Albania/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Algeria/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Andorra/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Angola/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Argentina/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Armenia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Australia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Austria/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Azerbaijan/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Barbados/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Belarus/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Belgium/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Bolivia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Bosnia-and-Herzegovina/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Brazil/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Bulgaria/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Canada/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Chile/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/China/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Colombia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Costa-Rica/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Croatia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Cyprus/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Czech-Republic/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Denmark/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Dominican-Republic/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Ecuador/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Egypt/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Estonia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Euro_area/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Faroe-Islands/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Finland/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/France/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Georgia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Germany/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Greece/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Hong-Kong/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Hungary/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Iceland/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/India/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Iran/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Ireland/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Israel/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Italy/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Jamaica/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Japan/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Jordan/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Kazakhstan/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Kenya/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Kyrgyzstan/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Latvia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Liechtenstein/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Lithuania/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Luxembourg/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Macao/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Macedonia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Malaysia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Malta/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Mauritius/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Mexico/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Moldova/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Mongolia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Montenegro/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Morocco/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Netherlands/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/New-Zealand/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Nigeria/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Norway/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Palestine/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Paraguay/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Philippines/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Poland/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Portugal/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Puerto-Rico/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Qatar/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Romania/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Russia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Rwanda/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Saudi-Arabia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Senegal/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Serbia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Seychelles/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Singapore/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Slovakia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Slovenia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/South-Africa/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/South-Korea/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Spain/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Sri-Lanka/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Sweden/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Switzerland/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Taiwan/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Tajikistan/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Thailand/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Trinidad-and-Tobago/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Tunisia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Turkey/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/USA/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Ukraine/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/United-Arab-Emirates/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/United-Kingdom/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Uruguay/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Venezuela/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Vietnam/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Zambia/unemployment_rate_monthly/
# https://www.theglobaleconomy.com/Zimbabwe/unemployment_rate_monthly/
