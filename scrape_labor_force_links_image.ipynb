# %%
import requests
import time
from urllib.parse import urlparse
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
import pandas as pd

# %%
# 1. Obtener el HTML de la página del ranking
load_dotenv()
url = os.getenv("TARGET_ULR_LABOR_FORCE")
BASE_URL = os.getenv("BASE_URL")

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
response.raise_for_status()  # Lanza error si la petición falla

# %%
# 2. Parsear HTML con BeautifulSoup
soup = BeautifulSoup(response.text, "html.parser")

# %%
# 3. Buscar la tabla principal y extraer los links
table = soup.find("table")
country_links = []


if table:
    rows = table.find_all("tr")
    for row in rows:
        cell = row.find("td")
        if cell and cell.a:
            relative_link = cell.a["href"]
            full_url = f"{BASE_URL}{relative_link}"
            country_links.append(full_url)

# Convertir la lista en DataFrame
df_links = pd.DataFrame(country_links, columns=["url"])

# Guardar como archivo Parquet
df_links.to_parquet("data/country_labor_force_links.parquet", index=False)

# %%
# 4. Mostrar resultado
print("Links encontrados:", df_links.size)
# Out:
# Links encontrados: 178

# %%
# configuracion necesaria para descargar datos

master_df = pd.DataFrame()

sleep_duration = 5

plots_dir = "plots"

os.makedirs(plots_dir, exist_ok=True)

# %%
def extraer_info_desde_url(url: str) -> tuple[str, str]:
    partes = url.strip("/").split("/")
    if len(partes) < 5:
        raise ValueError("URL no tiene el formato esperado.")
    pais = partes[-2]
    indicador = partes[-1]
    return pais, indicador

# %%
# Cargar los países válidos desde el archivo parquet
df_countries = pd.read_parquet("data/countries_with_hpi.parquet")
valid_countries = set(df_countries["country"].unique())

# %%
# logic and execution

start_time = time.time()

for url in country_links:
    pais, indicador = extraer_info_desde_url(url)

    if pais not in valid_countries:
        print(f"⏭️ País {pais} no está en la lista, se omite.")
        continue

    try:
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        img_tag = soup.find("img", id="graphImage")
        if not img_tag:
            print(f"❌ No se encontró la imagen para {pais} - {indicador}")
            continue

        img_url = img_tag["src"]
        if img_url.startswith("/"):
            img_url = base_url + img_url

        # Crear carpeta del país dentro de "plots"
        country_folder = os.path.join(plots_dir, pais)
        os.makedirs(country_folder, exist_ok=True)

        # Guardar imagen
        filename = f"{indicador}_{pais}.png"
        filepath = os.path.join(country_folder, filename)

        img_response = requests.get(img_url, headers=headers)
        with open(filepath, "wb") as f:
            f.write(img_response.content)

        print(f"✅ Imagen guardada en: {filepath}")

    except Exception as e:
        print(f"❌ Error procesando {url}: {e}")

    time.sleep(sleep_duration)

# Medición final
end_time = time.time()
total_sleep_time = len(valid_countries) * sleep_duration
effective_time = end_time - start_time - total_sleep_time

print(f"\n⏳ Tiempo total (incluyendo esperas): {end_time - start_time:.2f} s")
print(f"😴 Tiempo en espera: {total_sleep_time:.2f} s")
print(f"⚡ Tiempo efectivo de ejecución: {effective_time:.2f} s")
# Out:
# ✅ Imagen guardada en: plots\China\labor_force_China.png
# ✅ Imagen guardada en: plots\India\labor_force_India.png
# ✅ Imagen guardada en: plots\USA\labor_force_USA.png
# ✅ Imagen guardada en: plots\Indonesia\labor_force_Indonesia.png
# ✅ Imagen guardada en: plots\Brazil\labor_force_Brazil.png
# ⏭️ País Pakistan no está en la lista, se omite.
# ⏭️ País Nigeria no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Russia\labor_force_Russia.png
# ⏭️ País Bangladesh no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Japan\labor_force_Japan.png
# ⏭️ País Ethiopia no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Mexico\labor_force_Mexico.png
# ⏭️ País Vietnam no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Philippines\labor_force_Philippines.png
# ✅ Imagen guardada en: plots\Germany\labor_force_Germany.png
# ✅ Imagen guardada en: plots\Thailand\labor_force_Thailand.png
# ⏭️ País Democratic-Republic-of-the-Congo no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Turkey\labor_force_Turkey.png
# ✅ Imagen guardada en: plots\United-Kingdom\labor_force_United-Kingdom.png
# ⏭️ País Egypt no está en la lista, se omite.
# ✅ Imagen guardada en: plots\France\labor_force_France.png
# ⏭️ País Tanzania no está en la lista, se omite.
# ⏭️ País Iran no está en la lista, se omite.
# ✅ Imagen guardada en: plots\South-Korea\labor_force_South-Korea.png
# ✅ Imagen guardada en: plots\South-Africa\labor_force_South-Africa.png
# ✅ Imagen guardada en: plots\Colombia\labor_force_Colombia.png
# ✅ Imagen guardada en: plots\Italy\labor_force_Italy.png
# ⏭️ País Kenya no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Spain\labor_force_Spain.png
# ⏭️ País Burma-Myanmar no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Canada\labor_force_Canada.png
# ⏭️ País Argentina no está en la lista, se omite.
# ⏭️ País Uganda no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Peru\labor_force_Peru.png
# ✅ Imagen guardada en: plots\Poland\labor_force_Poland.png
# ✅ Imagen guardada en: plots\Malaysia\labor_force_Malaysia.png
# ⏭️ País Madagascar no está en la lista, se omite.
# ⏭️ País North-Korea no está en la lista, se omite.
# ⏭️ País Saudi-Arabia no está en la lista, se omite.
# ⏭️ País Angola no está en la lista, se omite.
# ⏭️ País Ghana no está en la lista, se omite.
# ⏭️ País Mozambique no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Australia\labor_force_Australia.png
# ⏭️ País Sudan no está en la lista, se omite.
# ⏭️ País Uzbekistan no está en la lista, se omite.
# ⏭️ País Algeria no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Morocco\labor_force_Morocco.png
# ⏭️ País Cameroon no está en la lista, se omite.
# ⏭️ País Ivory-Coast no está en la lista, se omite.
# ⏭️ País Iraq no está en la lista, se omite.
# ⏭️ País Venezuela no está en la lista, se omite.
# ⏭️ País Niger no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Netherlands\labor_force_Netherlands.png
# ✅ Imagen guardada en: plots\Chile\labor_force_Chile.png
# ⏭️ País Kazakhstan no está en la lista, se omite.
# ⏭️ País Cambodia no está en la lista, se omite.
# ⏭️ País Ecuador no está en la lista, se omite.
# ⏭️ País Sri-Lanka no está en la lista, se omite.
# ⏭️ País Afghanistan no está en la lista, se omite.
# ⏭️ País Burkina-Faso no está en la lista, se omite.
# ⏭️ País Nepal no está en la lista, se omite.
# ⏭️ País Malawi no está en la lista, se omite.
# ⏭️ País Mali no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Romania\labor_force_Romania.png
# ⏭️ País Yemen no está en la lista, se omite.
# ⏭️ País Guatemala no está en la lista, se omite.
# ⏭️ País United-Arab-Emirates no está en la lista, se omite.
# ⏭️ País Zambia no está en la lista, se omite.
# ⏭️ País Syria no está en la lista, se omite.
# ⏭️ País Zimbabwe no está en la lista, se omite.
# ⏭️ País Chad no está en la lista, se omite.
# ⏭️ País Bolivia no está en la lista, se omite.
# ⏭️ País Burundi no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Sweden\labor_force_Sweden.png
# ⏭️ País Senegal no está en la lista, se omite.
# ⏭️ País Azerbaijan no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Czech-Republic\labor_force_Czech-Republic.png
# ✅ Imagen guardada en: plots\Portugal\labor_force_Portugal.png
# ✅ Imagen guardada en: plots\Belgium\labor_force_Belgium.png
# ⏭️ País Dominican-Republic no está en la lista, se omite.
# ⏭️ País Rwanda no está en la lista, se omite.
# ⏭️ País Haiti no está en la lista, se omite.
# ⏭️ País Benin no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Switzerland\labor_force_Switzerland.png
# ✅ Imagen guardada en: plots\Hungary\labor_force_Hungary.png
# ⏭️ País Belarus no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Austria\labor_force_Austria.png
# ✅ Imagen guardada en: plots\Greece\labor_force_Greece.png
# ⏭️ País Honduras no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Israel\labor_force_Israel.png
# ⏭️ País Guinea no está en la lista, se omite.
# ⏭️ País Tunisia no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Hong-Kong\labor_force_Hong-Kong.png
# ✅ Imagen guardada en: plots\Singapore\labor_force_Singapore.png
# ⏭️ País Paraguay no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Serbia\labor_force_Serbia.png
# ⏭️ País Somalia no está en la lista, se omite.
# ⏭️ País Papua-New-Guinea no está en la lista, se omite.
# ⏭️ País Togo no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Denmark\labor_force_Denmark.png
# ⏭️ País Laos no está en la lista, se omite.
# ⏭️ País Nicaragua no está en la lista, se omite.
# ⏭️ País Kyrgyzstan no está en la lista, se omite.
# ⏭️ País Jordan no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Bulgaria\labor_force_Bulgaria.png
# ✅ Imagen guardada en: plots\New-Zealand\labor_force_New-Zealand.png
# ✅ Imagen guardada en: plots\Norway\labor_force_Norway.png
# ✅ Imagen guardada en: plots\Finland\labor_force_Finland.png
# ⏭️ País El-Salvador no está en la lista, se omite.
# ⏭️ País Kuwait no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Slovakia\labor_force_Slovakia.png
# ✅ Imagen guardada en: plots\Ireland\labor_force_Ireland.png
# ⏭️ País Sierra-Leone no está en la lista, se omite.
# ⏭️ País Tajikistan no está en la lista, se omite.
# ⏭️ País Oman no está en la lista, se omite.
# ⏭️ País Liberia no está en la lista, se omite.
# ⏭️ País Libya no está en la lista, se omite.
# ⏭️ País Republic-of-the-Congo no está en la lista, se omite.
# ⏭️ País Turkmenistan no está en la lista, se omite.
# ⏭️ País Costa-Rica no está en la lista, se omite.
# ⏭️ País Panama no está en la lista, se omite.
# ⏭️ País Qatar no está en la lista, se omite.
# ⏭️ País Lebanon no está en la lista, se omite.
# ⏭️ País Central-African-Republic no está en la lista, se omite.
# ⏭️ País Georgia no está en la lista, se omite.
# ⏭️ País Uruguay no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Croatia\labor_force_Croatia.png
# ⏭️ País Eritrea no está en la lista, se omite.
# ⏭️ País Jamaica no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Lithuania\labor_force_Lithuania.png
# ⏭️ País Armenia no está en la lista, se omite.
# ⏭️ País Moldova no está en la lista, se omite.
# ⏭️ País Mongolia no está en la lista, se omite.
# ⏭️ País Bosnia-and-Herzegovina no está en la lista, se omite.
# ⏭️ País Albania no está en la lista, se omite.
# ⏭️ País Mauritania no está en la lista, se omite.
# ⏭️ País Puerto-Rico no está en la lista, se omite.
# ⏭️ País Namibia no está en la lista, se omite.
# ⏭️ País Botswana no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Slovenia\labor_force_Slovenia.png
# ⏭️ País Lesotho no está en la lista, se omite.
# ⏭️ País Gambia no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Latvia\labor_force_Latvia.png
# ⏭️ País Bahrain no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Macedonia\labor_force_Macedonia.png
# ⏭️ País Gabon no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Estonia\labor_force_Estonia.png
# ✅ Imagen guardada en: plots\Cyprus\labor_force_Cyprus.png
# ⏭️ País Guinea-Bissau no está en la lista, se omite.
# ⏭️ País Equatorial-Guinea no está en la lista, se omite.
# ⏭️ País Trinidad-and-Tobago no está en la lista, se omite.
# ⏭️ País Mauritius no está en la lista, se omite.
# ⏭️ País Bhutan no está en la lista, se omite.
# ⏭️ País Solomon-Islands no está en la lista, se omite.
# ⏭️ País Swaziland no está en la lista, se omite.
# ⏭️ País Macao no está en la lista, se omite.
# ⏭️ País Fiji no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Luxembourg\labor_force_Luxembourg.png
# ✅ Imagen guardada en: plots\Malta\labor_force_Malta.png
# ⏭️ País Guyana no está en la lista, se omite.
# ⏭️ País Montenegro no está en la lista, se omite.
# ⏭️ País Maldives no está en la lista, se omite.
# ⏭️ País Djibouti no está en la lista, se omite.
# ⏭️ País Suriname no está en la lista, se omite.
# ⏭️ País Comoros no está en la lista, se omite.
# ✅ Imagen guardada en: plots\Iceland\labor_force_Iceland.png
# ⏭️ País Bahamas no está en la lista, se omite.
# ⏭️ País Brunei no está en la lista, se omite.
# ⏭️ País Cape-Verde no está en la lista, se omite.
# ⏭️ País Belize no está en la lista, se omite.
# ⏭️ País Barbados no está en la lista, se omite.
# ⏭️ País Vanuatu no está en la lista, se omite.
# ⏭️ País New-Caledonia no está en la lista, se omite.
# ⏭️ País Saint-Lucia no está en la lista, se omite.
# ⏭️ País Sao-Tome-and-Principe no está en la lista, se omite.
# ⏭️ País Samoa no está en la lista, se omite.
# ⏭️ País Saint-Vincent-and-the-Grenadines no está en la lista, se omite.
# ⏭️ País Tonga no está en la lista, se omite.
#
# ⏳ Tiempo total (incluyendo esperas): 405.49 s
# 😴 Tiempo en espera: 285.00 s
# ⚡ Tiempo efectivo de ejecución: 120.49 s

# %%
# obtain paraguay url
template_url = country_links[0]
country = "Paraguay"

# Separar por "/"
parts = template_url.strip("/").split("/")

# Reemplazar el país (posición 3: después del dominio)

parts[3] = country

# Reconstruir la URL
custom_url = "/".join(parts) + "/"

# %%
pais, indicador = extraer_info_desde_url(custom_url)

try:
    response = requests.get(custom_url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    img_tag = soup.find("img", id="graphImage")
    if not img_tag:
        print(f"❌ No se encontró la imagen para {pais} - {indicador}")
    else:
        img_url = img_tag["src"]
        if img_url.startswith("/"):
            img_url = base_url + img_url

        # Crear carpeta del país dentro de "plots"
        country_folder = os.path.join(plots_dir, pais)
        os.makedirs(country_folder, exist_ok=True)

        # Guardar imagen
        filename = f"{indicador}_{pais}.png"
        filepath = os.path.join(country_folder, filename)

        img_response = requests.get(img_url, headers=headers)
        with open(filepath, "wb") as f:
            f.write(img_response.content)

        print(f"✅ Imagen guardada en: {filepath}")

except Exception as e:
    print(f"❌ Error procesando {custom_url}: {e}")
# Out:
# ✅ Imagen guardada en: plots\Paraguay\labor_force_Paraguay.png
