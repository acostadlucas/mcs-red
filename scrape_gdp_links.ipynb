# %%
import requests
from bs4 import BeautifulSoup

# %%
# 1. Obtener el HTML de la página del ranking
url = "https://www.theglobaleconomy.com/rankings/gdp_current_local_currency/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
response.raise_for_status()  # Lanza error si la petición falla

# %%
# 2. Parsear HTML con BeautifulSoup
soup = BeautifulSoup(response.text, "html.parser")

# %%
# 3. Buscar la tabla principal y extraer los links
table = soup.find("table")
country_links = []

if table:
    rows = table.find_all("tr")
    for row in rows:
        cell = row.find("td")
        if cell and cell.a:
            relative_link = cell.a["href"]
            full_url = f"https://www.theglobaleconomy.com{relative_link}"
            country_links.append(full_url)

# %%
# 4. Mostrar resultado
print("Links encontrados:", len(country_links))
for link in country_links:
    print(link)
# Out:
# Links encontrados: 125
# https://www.theglobaleconomy.com/Afghanistan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Albania/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Algeria/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Argentina/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Armenia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Australia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Austria/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Azerbaijan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Bahamas/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Bahrain/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Bangladesh/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Belarus/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Belgium/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Bermuda/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Bolivia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Bosnia-and-Herzegovina/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Botswana/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Brazil/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Brunei/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Bulgaria/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Burkina-Faso/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Burma-Myanmar/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Cameroon/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Canada/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Cape-Verde/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Chile/gdp_current_local_currency/
# https://www.theglobaleconomy.com/China/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Colombia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Costa-Rica/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Croatia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Cyprus/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Czech-Republic/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Denmark/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Dominican-Republic/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Ecuador/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Egypt/gdp_current_local_currency/
# https://www.theglobaleconomy.com/El-Salvador/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Estonia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Euro_area/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Finland/gdp_current_local_currency/
# https://www.theglobaleconomy.com/France/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Georgia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Germany/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Ghana/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Greece/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Guatemala/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Guyana/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Hong-Kong/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Hungary/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Iceland/gdp_current_local_currency/
# https://www.theglobaleconomy.com/India/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Indonesia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Iran/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Ireland/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Israel/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Italy/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Jamaica/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Japan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Jordan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Kazakhstan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Kenya/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Kuwait/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Kyrgyzstan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Latvia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Lebanon/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Lesotho/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Lithuania/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Luxembourg/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Macao/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Macedonia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Malaysia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Maldives/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Malta/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Mauritius/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Mexico/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Moldova/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Mongolia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Montenegro/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Morocco/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Namibia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Netherlands/gdp_current_local_currency/
# https://www.theglobaleconomy.com/New-Zealand/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Nicaragua/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Nigeria/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Norway/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Oman/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Palestine/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Panama/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Paraguay/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Peru/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Philippines/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Poland/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Portugal/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Qatar/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Romania/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Russia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Rwanda/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Samoa/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Saudi-Arabia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Senegal/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Serbia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Seychelles/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Singapore/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Slovakia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Slovenia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/South-Africa/gdp_current_local_currency/
# https://www.theglobaleconomy.com/South-Korea/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Spain/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Sri-Lanka/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Sweden/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Switzerland/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Taiwan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Tajikistan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Tanzania/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Thailand/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Tunisia/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Turkey/gdp_current_local_currency/
# https://www.theglobaleconomy.com/USA/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Uganda/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Ukraine/gdp_current_local_currency/
# https://www.theglobaleconomy.com/United-Kingdom/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Uruguay/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Uzbekistan/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Vietnam/gdp_current_local_currency/
# https://www.theglobaleconomy.com/Zambia/gdp_current_local_currency/
